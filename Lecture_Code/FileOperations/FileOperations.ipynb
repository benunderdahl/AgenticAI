# %% [markdown]
# # File Operations

# %%
# files can be accessed in python using the open() method
'''
    it can take different params 
        - r : read file
        - a : append to the file at the end of file
        - w : write to file, will create if file doesnt exist
        - x : create file if doesnt exist, error if it does
'''

# Types of edata that can be read in
    # t- text data and b - byte data (usually images)
    # if nothing specified the default will be rt (reading text)
    # open("file.txt") it will open in read mode and treated as text file

# both canonical and relative path can be used to open files
# practice will be done using a pride and prejudice text file

file_path = './pp.txt'
with open(file_path) as text:
    print(text)
# Out:
# <_io.TextIOWrapper name='./pp.txt' mode='r' encoding='UTF-8'>
