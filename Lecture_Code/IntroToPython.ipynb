# %%
# Int, String, Float, Boolean, Char, Complex

print("This is a 'String'")  # quote within string
print("""creating a multiple  
line string""") # multi line string
string_var = "Im in a variable" 
print(string_var) # storing string in variable
# Out:
# This is a 'String'
#  creating a multiple
# line string
# Im in a variable

# %%
int_var = 4

float_var = 4.232

complex_var = 3 + 3j

# %%
# operations in python
x = 1323
y = 122
print(x+y) # addition
print(x-y) # subtraction
print(x*y) # multiplication
print(x/y) # returns decimal result
print(x**y) # x to the power y
print(x%y) # returns remainder
# Out:
# 1445
# 1201
# 161406
# 10.844262295081966
# 
# 103

# %%
# Collections in python
# Include: List, Dictionary, Set, Trees, Tuples

# %%
# Booleans
# True/False , 1/0, yes/no 

true = True # capitalization important for assignment
false = False 

# 1 is considered true 0 is false actually any other value other than 1 is true
if(123):  # same as if(True)
    print("true")

if(0):     #same as if(False)
    print("this will not print")
# Out:
# true

# %%
# Casting in python

# Casting into a string is very safe everything can be turned into a string ex. int, bool, float
x = 1
print(type(x)) #of class int

y = str(x)
print(type(y)) # of class str

z = "not an int"
x = int(z) # this will not work and throw an error with invalid literal

z = "4"
x = int(z)
print(x)  #this will work because it is a valid literal
# Out:
# <class 'int'>
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 11
#       7 y = str(x)
#       8 print(type(y)) # of class str
#       9
#      10 z = "not an int"
# ---> 11 x = int(z) # this will not work and throw an error with invalid literal
#      12
#      13 z = "4"
#      14 x = int(z)
#
# ValueError: invalid literal for int() with base 10: 'not an int'

# %% [markdown]
# # Keywords in Python
# ---
#
# ## Boolean & Null Values:
# - True
# - False
# - None
# ---
#
# ## Logical and Membership operators
# - and
# - or
# - not
# - in
# - is
# ---
#
# ## Control Flow
# - if
# - elif
# - else
# - match
# - case
# ---
#
# ## Iteration and Loops
# - for
# - while
# - break
# - continue
# - pass
# ---
#
# ## Functions and Classes
# - def
# - class
# - return
# - lambda
# - yield
# ---
#
# ## Exception Handling
# - try
# - except
# - finally
# - raise
# - assert
# ---
#
# ### Variable Handling & Scope
# - global
# - nonlocal
# - del
# ---
#
# ## Modules & Imports
# - import
# - from
# - as
# ---
#
# ## Asynchronous Programming
# - async
# - await
# ---
#
# ## Context Management
# - with
# ---
#
# ### General Rules and Guidelines
# Case Sensitivity
# : keywords are generally lowercase except a few such as True, False, None
#
# Reassignment
# : Trying to assign a value to a keyword will result in a syntax error
#
# PEP8
# : Guideline for good practice when styling and structuring code for readability and standardization
